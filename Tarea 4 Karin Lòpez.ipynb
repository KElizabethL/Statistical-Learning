# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
dataset= pd.read_csv('train_HP.csv')

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
def getNanColNames(df):
    colnames = df.columns
    cols_con_na = []
    for col in colnames:
        if(df[col].isnull().sum() > 0):
            cols_con_na.append(col)
    return cols_con_na

# %%
getNanColNames(dataset)
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
def getCategoryVars(df):
    colnames = df.columns
    cat_cols = []
    for col in colnames:
        if(df[col].dtype == 'object'):
            cat_cols.append(col)
    return cat_cols
cat_cols = getCategoryVars(dataset)
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %% [markdown]
# ## Variables Categoricas

# %% [markdown]
# ## Frequency Encoding

# %%
def FreqEncoding(df, map_type='freq'):
    colnames = df.columns
    for col in colnames:
        if(df[col].dtype == 'object'):
            factor_div = 1 if (map_type == 'freq') else len(df[col])
            mapper = (df[col].value_counts().sort_values(ascending=False)/factor_div).to_dict()
            df[col] = df[col].map(mapper) 
            
FreqEncoding(dataset)
dataset
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60    1151.0         65.0     8450  1454.0    NaN
# 1        2          20    1151.0         80.0     9600  1454.0    NaN
# 2        3          60    1151.0         68.0    11250  1454.0    NaN
# 3        4          70    1151.0         60.0     9550  1454.0    NaN
# 4        5          60    1151.0         84.0    14260  1454.0    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60    1151.0         62.0     7917  1454.0    NaN
# 1456  1457          20    1151.0         85.0    13175  1454.0    NaN
# 1457  1458          70    1151.0         66.0     9042  1454.0    NaN
# 1458  1459          20    1151.0         68.0     9717  1454.0    NaN
# 1459  1460          20    1151.0         75.0     9937  1454.0    NaN
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 0        925.0       1311.0     1459.0  ...         0     NaN    NaN
# 1        925.0       1311.0     1459.0  ...         0     NaN    NaN
# 2        484.0       1311.0     1459.0  ...         0     NaN    NaN
# 3        484.0       1311.0     1459.0  ...         0     NaN    NaN
# 4        484.0       1311.0     1459.0  ...         0     NaN    NaN
# ...        ...          ...        ...  ...       ...     ...    ...
# 1455     925.0       1311.0     1459.0  ...         0     NaN    NaN
# 1456     925.0       1311.0     1459.0  ...         0     NaN  157.0
# 1457     925.0       1311.0     1459.0  ...         0     NaN   59.0
# 1458     925.0       1311.0     1459.0  ...         0     NaN    NaN
# 1459     925.0       1311.0     1459.0  ...         0     NaN    NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0             NaN        0       2    2008    1267.0         1198.0     208500
# 1             NaN        0       5    2007    1267.0         1198.0     181500
# 2             NaN        0       9    2008    1267.0         1198.0     223500
# 3             NaN        0       2    2006    1267.0          101.0     140000
# 4             NaN        0      12    2008    1267.0         1198.0     250000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1455          NaN        0       8    2007    1267.0         1198.0     175000
# 1456          NaN        0       2    2010    1267.0         1198.0     210000
# 1457         49.0     2500       5    2010    1267.0         1198.0     266500
# 1458          NaN        0       4    2010    1267.0         1198.0     142125
# 1459          NaN        0       6    2008    1267.0         1198.0     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# ## Variables Numericas

# %%
def getContinuesCols(df):
    colnames = df.columns
    numeric_continues_vars = []
    for col in colnames:
        unique_values =len (df[col].unique())
        if((df[col].dtype != 'object') and (unique_values > 30)):
            numeric_continues_vars.append(col)
    return numeric_continues_vars
numeric_cont_vars = getContinuesCols(dataset)
numeric_cont_vars
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
dataset_temp = dataset.loc[:, ['LotArea', 'SalePrice']]
dataset_temp.head()
# Out:
#    LotArea  SalePrice
# 0     8450     208500
# 1     9600     181500
# 2    11250     223500
# 3     9550     140000
# 4    14260     250000

# %%
dataset_temp['LotArea_log'] = np.log(dataset['LotArea'])

# %%
dataset_temp['LotArea_inv'] = (1 / dataset['LotArea'])

# %%
dataset_temp['LotArea_quadratic'] = (dataset['LotArea']**2)

# %%
np.corrcoef(dataset_temp['LotArea_quadratic'], dataset_temp['SalePrice'])[0, 1]
# Out:
# 0.1144684470003984

# %%
dataset_temp['LotArea_boxCox'], lambdaX = stats.boxcox(dataset_temp['LotArea'])

# %%
dataset_temp.to_csv('C:/Users/Klopez/Desktop/Statistical Learning/tarea_4.csv',index=False)
